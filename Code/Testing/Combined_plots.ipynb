# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\Saad.LAKES\Desktop\Lakes-Software-New\Notebooks\Twenty Four Hour Ahead\Jahra\Ozone Univariate\Combined Values.xlsx'
path = path.replace('\\','/')

# %%
df_att = pd.read_excel(path,sheet_name='Simple')

# %%
start=0
end = 250
plt.figure(figsize=(18,10))
plt.plot(df_att['Actual'][start:end],color='r',label='Actual')
plt.plot(df_att['Attention Ensemble'][start:end],color='b',label='NN Ensemble')
# plt.plot(df_att['Average Ensemble'][start:end],color='g',label='Average Ensemble')
plt.plot(df_att['Max Ensemble'][start:end],color='y',label='Max Ensemble')
plt.plot(df_att['Min Ensemble'][start:end],color='m',label='NN Ensemble')
plt.legend()
plt.show()

# %%
start=0
end = 250
plt.figure(figsize=(18,10))
plt.plot(df_att['Actual'][start:end],color='r',label='Actual')
plt.plot(df_att['Simple Ensemble'][start:end],color='b',label='NN Ensemble')
plt.plot(df_att['Average Ensemble'][start:end],color='g',label='Average Ensemble')
# plt.plot(df_att['Max Ensemble'][start:end],color='y',label='Max Ensemble')
# plt.plot(df_att['Min Ensemble'][start:end],color='m',label='NN Ensemble')
plt.legend()
plt.show()
